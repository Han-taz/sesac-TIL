# %% [markdown]
# ### 복습

# %%
import pandas as pd
import numpy as np

# %%
dat=pd.read_csv('midwest.csv')

# %%
dat
# Out:
#       PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0     561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1     562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2     563       BOND    IL  0.022     14991   681.409091     14477       429
# 3     564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4     565      BROWN    IL  0.018      5836   324.222222      5264       547
# ..    ...        ...   ...    ...       ...          ...       ...       ...
# 432  3048   WAUKESHA    WI  0.034    304715  8962.205880    298313      1096
# 433  3049    WAUPACA    WI  0.045     46104  1024.533330     45695        22
# 434  3050   WAUSHARA    WI  0.037     19385   523.918919     19094        29
# 435  3051  WINNEBAGO    WI  0.035    140320  4009.142860    136822       697
# 436  3052       WOOD    WI  0.048     73605  1533.437500     72157        90
#
# ...

# %%
dat.head()
# Out:
#    PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0  561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1  562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2  563       BOND    IL  0.022     14991   681.409091     14477       429
# 3  564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4  565      BROWN    IL  0.018      5836   324.222222      5264       547
#
#    popamerindian  popasian  ...  percollege  percprof  poppovertyknown  \
# 0             98       249  ...   19.631392  4.355859            63628
# 1             19        48  ...   11.243308  2.870315            10529
# 2             35        16  ...   17.033819  4.488572            14235
# 3             46       150  ...   17.278954  4.197800            30337
# 4             14         5  ...   14.475999  3.367680             4815
#
#    percpovertyknown  percbelowpoverty  percchildbelowpovert  percadultpoverty  \
# ...

# %%
dat.describe()
# Out:
#                PID        area      poptotal    popdensity      popwhite  \
# count   437.000000  437.000000  4.370000e+02    437.000000  4.370000e+02
# mean   1437.338673    0.033169  9.613030e+04   3097.742985  8.183992e+04
# std     876.390266    0.014679  2.981705e+05   7664.751786  2.001966e+05
# min     561.000000    0.005000  1.701000e+03     85.050000  4.160000e+02
# 25%     670.000000    0.024000  1.884000e+04    622.407407  1.863000e+04
# 50%    1221.000000    0.030000  3.532400e+04   1156.208330  3.447100e+04
# 75%    2059.000000    0.038000  7.565100e+04   2330.000000  7.296800e+04
# max    3052.000000    0.110000  5.105067e+06  88018.396600  3.204947e+06
#
#            popblack  popamerindian       popasian       popother   percwhite  \
# count  4.370000e+02     437.000000     437.000000     437.000000  437.000000
# mean   1.102388e+04     343.109840    1310.464531    1612.931350   95.558441
# std    7.895827e+04     868.926751    9518.394189   18526.540699    7.087358
# ...

# %%
dat.columns
# Out:
# Index(['PID', 'county', 'state', 'area', 'poptotal', 'popdensity', 'popwhite',
#        'popblack', 'popamerindian', 'popasian', 'popother', 'percwhite',
#        'percblack', 'percamerindan', 'percasian', 'percother', 'popadults',
#        'perchsd', 'percollege', 'percprof', 'poppovertyknown',
#        'percpovertyknown', 'percbelowpoverty', 'percchildbelowpovert',
#        'percadultpoverty', 'percelderlypoverty', 'inmetro', 'category'],
#       dtype='object')

# %%
dat=dat.rename({'popblack':'black','popwhite':'white'},axis=1)

# %%
dat
# Out:
#       PID     county state   area  poptotal   popdensity   white  black  \
# 0     561      ADAMS    IL  0.052     66090  1270.961540   63917   1702
# 1     562  ALEXANDER    IL  0.014     10626   759.000000    7054   3496
# 2     563       BOND    IL  0.022     14991   681.409091   14477    429
# 3     564      BOONE    IL  0.017     30806  1812.117650   29344    127
# 4     565      BROWN    IL  0.018      5836   324.222222    5264    547
# ..    ...        ...   ...    ...       ...          ...     ...    ...
# 432  3048   WAUKESHA    WI  0.034    304715  8962.205880  298313   1096
# 433  3049    WAUPACA    WI  0.045     46104  1024.533330   45695     22
# 434  3050   WAUSHARA    WI  0.037     19385   523.918919   19094     29
# 435  3051  WINNEBAGO    WI  0.035    140320  4009.142860  136822    697
# 436  3052       WOOD    WI  0.048     73605  1533.437500   72157     90
#
#      popamerindian  popasian  ...  percollege  percprof  poppovertyknown  \
# ...

# %%
dat['WH']=(dat['white']-dat['black'])/dat['white']*100

# %%
dat['WH']
# Out:
# 0      97.337172
# 1      50.439467
# 2      97.036679
# 3      99.567203
# 4      89.608663
#          ...
# 432    99.632601
# 433    99.951855
# 434    99.848120
# 435    99.490579
# 436    99.875272
# Name: WH, Length: 437, dtype: float64

# %%
len(dat['WH'].unique())
# Out:
# 437

# %%
dat['WH']
# Out:
# 0      97.337172
# 1      50.439467
# 2      97.036679
# 3      99.567203
# 4      89.608663
#          ...
# 432    99.632601
# 433    99.951855
# 434    99.848120
# 435    99.490579
# 436    99.875272
# Name: WH, Length: 437, dtype: float64

# %%
dat['WH'].value_counts()
# Out:
# 97.337172    1
# 90.220051    1
# 98.865269    1
# 90.932728    1
# 97.805449    1
#             ..
# 99.022613    1
# 99.104810    1
# 98.756040    1
# 99.859241    1
# 99.875272    1
# Name: WH, Length: 437, dtype: int64

# %%
dat.sort_values('WH',ascending=False)
# Out:
#       PID       county state   area  poptotal    popdensity    white    black  \
# 404  3020    MENOMINEE    WI  0.021      3890    185.238095      416        0
# 192   753        WHITE    IN  0.030     23265    775.500000    23127        2
# 39    600       JASPER    IL  0.029     10609    365.827586    10574        1
# 425  3041       TAYLOR    WI  0.057     18901    331.596491    18807        2
# 253  1256  MONTMORENCY    MI  0.033      8936    270.787879     8861        1
# ..    ...          ...   ...    ...       ...           ...      ...      ...
# 81    642     ST CLAIR    IL  0.040    262852   6571.300000   187866    71275
# 15    576         COOK    IL  0.058   5105067  88018.396600  3204947  1317147
# 76    637      PULASKI    IL  0.011      7523    683.909091     5032     2466
# 1     562    ALEXANDER    IL  0.014     10626    759.000000     7054     3496
# 275  1278        WAYNE    MI  0.035   2111687  60333.914300  1212007   849109
#
# ...

# %%
dat.sort_values('WH',ascending=False)['county']
# Out:
# 404      MENOMINEE
# 192          WHITE
# 39          JASPER
# 425         TAYLOR
# 253    MONTMORENCY
#           ...
# 81        ST CLAIR
# 15            COOK
# 76         PULASKI
# 1        ALEXANDER
# 275          WAYNE
# Name: county, Length: 437, dtype: object

# %%
dat.sort_values('WH',ascending=False)['county'][0:10]
# Out:
# 404      MENOMINEE
# 192          WHITE
# 39          JASPER
# 425         TAYLOR
# 253    MONTMORENCY
# 187         WARREN
# 156         MORGAN
# 390           IRON
# 85           SCOTT
# 6          CALHOUN
# Name: county, dtype: object

# %%
dat['AA']=np.where(dat['WH']>=30,"LARGE",
np.where(dat['WH']>=20,"middle",'small'))

# %%
dat['AA']
# Out:
# 0      LARGE
# 1      LARGE
# 2      LARGE
# 3      LARGE
# 4      LARGE
#        ...
# 432    LARGE
# 433    LARGE
# 434    LARGE
# 435    LARGE
# 436    LARGE
# Name: AA, Length: 437, dtype: object

# %%
len(dat['AA'].unique())
# Out:
# 2

# %%
dat['AA'].value_counts()
# Out:
# LARGE     436
# middle      1
# Name: AA, dtype: int64

# %%
dat.sort_values('AA',ascending=False)[['county']][:10]
# Out:
#         county
# 275      WAYNE
# 288      CLARK
# 299  FAIRFIELD
# 298       ERIE
# 297   DELAWARE
# 296   DEFIANCE
# 295      DARKE
# 294   CUYAHOGA
# 293   CRAWFORD
# 292  COSHOCTON

# %%
dt=pd.read_csv('ecommerse.csv')

# %%
dt.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
dt.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %% [markdown]
# 1. 총구매 금액의 평균
# 2. 웹 사이트 언어로 영어를 쓰는 사람의 수
# 3. 고객들의 직업 수
# 4. 직업별 구매 평균금액이 가장 높은 직업은?
# 5. 직업별 구매 평균금액이 가장 낮은 직업은?
# 6. 가장 많은 구매(횟수)를 한 직업은?
# 7. bondellen@williams-garza.com 메일주소를 가진 사용자의 구매금액은?
# 8. MasterCard를 사용했으며 50달러 이상 구매한 사용자는 몇 명?
# 9. 윈도우를 사용하는 사용자는 몇 명(Browser Info)?
# 10. 전체 사용자 중 윈도우,Linux, Mac 운영체제를 사요하는 사용자의 비율은?

# %%
###useragent= 크롤링할 때 씀

# %%
###1
dt['Purchase Price']
# Out:
# 0       98.14
# 1       70.73
# 2        0.95
# 3       78.04
# 4       77.82
#         ...
# 9995    82.21
# 9996    25.63
# 9997    83.98
# 9998    38.84
# 9999    67.59
# Name: Purchase Price, Length: 10000, dtype: float64

# %%
dt['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %%
###2
len(dt[dt['Language']=='en'])
# Out:
# 1098

# %%
len(dt[dt['Language'].str.upper()=='EN'])
# Out:
# 1098

# %%
###3
len(dt['Job'].unique())
# Out:
# 623

# %%
###4
dt.groupby(['Job','Purchase Price']).sum()
# Out:
#                                         Credit Card  CC Security Code  \
# Job                Purchase Price
# Academic librarian 0.76            5456352641046696               120
#                    15.37           6011998459310685                65
#                    22.56           5344177216341636               386
#                    29.55           3088397087539796                27
#                    53.01           4036104378992887               932
# ...                                             ...               ...
# Youth worker       47.90            372135746508054               858
#                    82.12            180088065467158               382
#                    90.47               639010570211                62
#                    93.97            372747486775386               267
#                    98.62            378758186278575               632
#
#                                          PPM
# Job                Purchase Price
# ...

# %%
dt.groupby("Job")['Purchase Price'].sum().sort_values(ascending=False).head(1)
# Out:
# Job
# Dietitian    1605.3
# Name: Purchase Price, dtype: float64

# %%
dt.groupby("Job")['Purchase Price'].sum().sort_values(ascending=False).index[0]## 이름뽑기
# Out:
# 'Dietitian'

# %%
dt.groupby("Job")['Purchase Price'].sum().sort_values(ascending=False).values[0]## 벨류값뽑기
# Out:
# 1605.3

# %%
###5
dt.groupby('Job')['Purchase Price'].sum().sort_values().index[0]
# Out:
# 'Art gallery manager'

# %%
dt.groupby("Job")['Purchase Price'].sum().sort_values().head(1)
# Out:
# Job
# Art gallery manager    219.05
# Name: Purchase Price, dtype: float64

# %%
dt.groupby("Job")['Purchase Price'].sum().sort_values().values[1]
# Out:
# 234.07999999999998

# %%
###6
dt['Job'].value_counts().head(1)
# Out:
# Interior and spatial designer    31
# Name: Job, dtype: int64

# %%
###6
dt['Job'].value_counts().index[0]
# Out:
# 'Interior and spatial designer'

# %%
###6
dt['Job'].value_counts().values[0]
# Out:
# 31

# %%
##7
dt[dt['Email'].str.lower()=='bondellen@williams-garza.com'.lower()]['Purchase Price'].values[0]
# Out:
# 77.88

# %%
dat
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
len(dt[(dt['CC Provider'].str.lower()=='Mastercard'.lower()) & (dt['Purchase Price']>=50)])
# Out:
# 405

# %%
###9. 윈도우를 사용하는 사용자는 몇 명(Browser Info)? 유저 에이전트
dt['Browser Info'].str.lower().str.contains('windows')
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: Browser Info, Length: 10000, dtype: bool

# %%
## in 
## contains

# %%
dt[dt['Browser Info'].str.lower().str.contains('windows')]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 14    8774 Jason Keys Suite 427\nEast Scottborough, ...  70 zH       AM
# 15       31730 Chelsea Crest\nBlakemouth, CT 90395-0620  41 Cj       PM
# ...                                                 ...    ...      ...
# 9988      0154 Green Forest\nNew Timothy, IL 33670-4620  11 MC       AM
# 9989         5674 Cruz Trace\nNew Shelby, KY 51047-5469  12 Kf       AM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
len(dt[dt['Browser Info'].str.lower().str.contains('windows')])
# Out:
# 4994

# %%
windows=len(dt[dt['Browser Info'].str.lower().str.contains('windows')])

# %%
windows/len(dt)*100
# Out:
# 49.94

# %%
w=windows/len(dt)*100

# %%
Linux=len(dt[dt['Browser Info'].str.lower().str.contains('linux')])

# %%
Linux/len(dt)*100
# Out:
# 23.22

# %%
l=Linux/len(dt)*100

# %%
Mac=len(dt[dt['Browser Info'].str.lower().str.contains('mac')])

# %%
Mac/len(dt)*100
# Out:
# 26.840000000000003

# %%
m=Mac/len(dt)*100

# %%
w+l+m
# Out:
# 73.28

# %%
for os in ['windows','linux','mac'] :
    p=len(dt[dt['Browser Info'].str.lower().str.contains(os)])
    print(f'%7s : %.2f'%(os,p/len(dt)*100))
# Out:
# windows : 49.94
#   linux : 23.22
#     mac : 26.84

# %%
dt=pd.DataFrame({'gender':["M","F",None,"M","F"],
                 'score':[5,4,3,4,None]})

# %%
dt
# Out:
#   gender  score
# 0      M    5.0
# 1      F    4.0
# 2   None    3.0
# 3      M    4.0
# 4      F    NaN

# %%
dt.to_csv('score.csv',index=False)

# %%
dat=pd.read_csv('score.csv')

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   gender  4 non-null      object
#  1   score   4 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 208.0+ bytes

# %%
dat.isnull()
# Out:
#    gender  score
# 0   False  False
# 1   False  False
# 2    True  False
# 3   False  False
# 4   False   True

# %%
dat.isnull().sum()
# Out:
# gender    1
# score     1
# dtype: int64

# %%
dat[dat.isnull()]
# Out:
#   gender  score
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN

# %%
dat.dropna()### null값 지우기
# Out:
#   gender  score
# 0      M    5.0
# 1      F    4.0
# 3      M    4.0

# %%
dat.dropna(subset=['gender']) #$### ' '안에 있는 값의 null값 지우기
# Out:
#   gender  score
# 0      M    5.0
# 1      F    4.0
# 3      M    4.0
# 4      F    NaN

# %% [markdown]
# null,NAN,Na None == None

# %%
dt
# Out:
#    gender  score
# 0     3.0    5.0
# 1     3.0    4.0
# 2     3.0    3.0
# 3     3.0    4.0
# 4     3.0    0.0

# %%
dt[['score','gender']].fillna(0, inplace=True)

# %%
dt
# Out:
#   gender  score
# 0      M    5.0
# 1      F    4.0
# 2   None    3.0
# 3      M    4.0
# 4      F    0.0

# %%
data=pd.read_csv('score.csv')

# %%
dt
# Out:
#    gender  score
# 0     1.0    5.0
# 1     2.0    4.0
# 2     3.0    3.0
# 3     1.0    4.0
# 4     2.0    0.0

# %%
data['score'].fillna(data['score'].mean())
# Out:
# 0    5.0
# 1    4.0
# 2    3.0
# 3    4.0
# 4    4.0
# Name: score, dtype: float64

# %%
data['score'].fillna(data['score'].median())
# Out:
# 0    5.0
# 1    4.0
# 2    3.0
# 3    4.0
# 4    4.0
# Name: score, dtype: float64

# %% [markdown]
# ###  dt['gender']/ m->1 f->2 gender 비어있는 곳에 3을 채우세요
# ###  dt['score']-> score에 빈 곳에 50을 채우기

# %%
Dat
# Out:
#    gender  score
# 0     3.0    5.0
# 1     3.0    4.0
# 2     3.0    3.0
# 3     3.0    4.0
# 4     3.0    NaN

# %%
Dat=pd.DataFrame({'gender':["M","F",None,"M","F"],
                 'score':[5,4,3,4,None]})

# %%
Dat
# Out:
#   gender  score
# 0      M    5.0
# 1      F    4.0
# 2   None    3.0
# 3      M    4.0
# 4      F    NaN

# %%
maping={'M':1,'F':2}

# %%
Dat['gender']=Dat['gender'].map(maping)

# %%
Dat['gender']
# Out:
# 0       M
# 1       F
# 2    None
# 3       M
# 4       F
# Name: gender, dtype: object

# %%
Dat['gender'].fillna(3,inplace=True)

# %%
Dat
# Out:
#    gender  score
# 0     1.0    5.0
# 1     2.0    4.0
# 2     3.0    3.0
# 3     1.0    4.0
# 4     2.0    NaN

# %%
Dat['score'].fillna(50,inplace=True)

# %%
Dat
# Out:
#    gender  score
# 0     1.0    5.0
# 1     2.0    4.0
# 2     3.0    3.0
# 3     1.0    4.0
# 4     2.0   50.0

# %%
Dat['gender'].unique()
# Out:
# array([1., 2., 3.])

# %%
Dat['score'].fillna(Dat['score'].median(),inplace=True)

# %%
Dat['score']
# Out:
# 0    5.0
# 1    4.0
# 2    3.0
# 3    4.0
# 4    4.0
# Name: score, dtype: float64

# %%
Dat['score'].median()
# Out:
# 4.0

# %%
### score의 이상치가 score의 평균보다 높다면 score의 중간값으로 출력하고 아니면 그대로 score값출력
Dat['score']=np.where(Dat['score']>Dat['score'].mean(),Dat['score'].median(),Dat['score'])

# %%
Dat
# Out:
#    gender  score
# 0     1.0    4.0
# 1     2.0    4.0
# 2     3.0    3.0
# 3     1.0    4.0
# 4     2.0    4.0

# %%
import pydataset as pds

# %%
mpg=pds.data('mpg')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
mpg_df=mpg.groupby('drv',as_index=False)['hwy'].mean()

# %%
mpg_df
# Out:
#   drv        hwy
# 0   4  19.174757
# 1   f  28.160377
# 2   r  21.000000

# %%
import seaborn as sns

# %%
sns.barplot(data=mpg_df, x='drv', y='hwy');

# %%
mpg_df.sort_values('hwy', ascending=False,inplace=False)
# Out:
#   drv        hwy
# 1   f  28.160377
# 2   r  21.000000
# 0   4  19.174757

# %%
sns.barplot(data=mpg_df, x='drv', y='hwy');

# %%
eco=pds.data('economics')

# %%
eco
# Out:
#            date     pce     pop  psavert  uempmed  unemploy
# 1    1967-06-30   507.8  198712      9.8      4.5      2944
# 2    1967-07-31   510.9  198911      9.8      4.7      2945
# 3    1967-08-31   516.7  199113      9.0      4.6      2958
# 4    1967-09-30   513.3  199311      9.8      4.9      3143
# 5    1967-10-31   518.5  199498      9.7      4.7      3066
# ..          ...     ...     ...      ...      ...       ...
# 474  2006-11-30  9478.5  301070     -1.1      7.3      6849
# 475  2006-12-31  9540.3  301296     -0.9      8.1      7017
# 476  2007-01-31  9610.6  301481     -1.0      8.1      6865
# 477  2007-02-28  9653.0  301684     -0.7      8.5      6724
# 478  2007-03-31  9705.0  301913     -1.3      8.7      6801
#
# [478 rows x 6 columns]

# %%
eco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 1 to 478
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      478 non-null    object
#  1   pce       478 non-null    float64
#  2   pop       478 non-null    int64
#  3   psavert   478 non-null    float64
#  4   uempmed   478 non-null    float64
#  5   unemploy  478 non-null    int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 26.1+ KB

# %%
eco['date2']=pd.to_datetime(eco['date'])

# %%
eco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 1 to 478
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      478 non-null    object
#  1   pce       478 non-null    float64
#  2   pop       478 non-null    int64
#  3   psavert   478 non-null    float64
#  4   uempmed   478 non-null    float64
#  5   unemploy  478 non-null    int64
#  6   date2     478 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(2), object(1)
# memory usage: 29.9+ KB

# %%
eco['date2'].dt.year####  datetime64[ns]에만 사용할 수 있다.
# Out:
# 1      1967
# 2      1967
# 3      1967
# 4      1967
# 5      1967
#        ...
# 474    2006
# 475    2006
# 476    2007
# 477    2007
# 478    2007
# Name: date2, Length: 478, dtype: int64

# %%
eco['date2'].dt.month
# Out:
# 1       6
# 2       7
# 3       8
# 4       9
# 5      10
#        ..
# 474    11
# 475    12
# 476     1
# 477     2
# 478     3
# Name: date2, Length: 478, dtype: int64

# %%
eco['date2'].dt.day
# Out:
# 1      30
# 2      31
# 3      31
# 4      30
# 5      31
#        ..
# 474    30
# 475    31
# 476    31
# 477    28
# 478    31
# Name: date2, Length: 478, dtype: int64

# %%
eco.sort_values('date2')
# Out:
#            date     pce     pop  psavert  uempmed  unemploy      date2
# 1    1967-06-30   507.8  198712      9.8      4.5      2944 1967-06-30
# 2    1967-07-31   510.9  198911      9.8      4.7      2945 1967-07-31
# 3    1967-08-31   516.7  199113      9.0      4.6      2958 1967-08-31
# 4    1967-09-30   513.3  199311      9.8      4.9      3143 1967-09-30
# 5    1967-10-31   518.5  199498      9.7      4.7      3066 1967-10-31
# ..          ...     ...     ...      ...      ...       ...        ...
# 474  2006-11-30  9478.5  301070     -1.1      7.3      6849 2006-11-30
# 475  2006-12-31  9540.3  301296     -0.9      8.1      7017 2006-12-31
# 476  2007-01-31  9610.6  301481     -1.0      8.1      6865 2007-01-31
# 477  2007-02-28  9653.0  301684     -0.7      8.5      6724 2007-02-28
# 478  2007-03-31  9705.0  301913     -1.3      8.7      6801 2007-03-31
#
# [478 rows x 7 columns]

# %%
sns.lineplot(data=eco, x='date2',y='unemploy');

# %%
sns.lineplot(data=eco, x='date',y='unemploy');

# %%
eco['month']=eco['date2'].dt.month

# %%
sns.lineplot(data=eco, x='month',y='unemploy');

# %%
eco_df=eco.groupby('month',as_index=False)['unemploy'].mean()

# %%
sns.lineplot(data=eco_df, x='month',y='unemploy');

# %%
eco['year'].unique()
# Out:
# array([1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977,
#        1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988,
#        1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007], dtype=int64)

# %%
eco['year']=eco['date2'].dt.year

# %%
eco_df=eco.groupby('year',as_index=False)['unemploy'].mean()

# %%
sns.lineplot(data=eco_df, x='year',y='unemploy');

# %%
eco['day']=eco['date2'].dt.day

# %%
eco_df=eco.groupby('day',as_index=False)['unemploy'].mean()

# %%
sns.lineplot(data=eco_df, x='day',y='unemploy');
